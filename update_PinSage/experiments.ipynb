# %% [markdown]
# * DataSet: MovieLens-1m

# %%
# %run model.py data/data_ml.pkl models/model_ml_optuna --num-neighbors 2 --hidden-dims 60 --batch-size 64 --num-epochs 7 --batches-per-epoch 10000 --device 'cuda' --k 20 --agg_att 'mean' --num-layers 1 --num-heads 3 --lr 0.000508
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10000/10000 [04:59<00:00, 33.42it/s]
# Rec by user emb (0.08891556291390902, 0.08066146787948279, 0.2966610352393153)
#  Rec by latest item (0.07634105960265121, 0.06891533857516173, 0.24269155093271552)
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10000/10000 [04:32<00:00, 36.76it/s]
# Rec by user emb (0.09005794701986927, 0.08387337907548434, 0.30230989417799964)
#  Rec by latest item (0.08199503311258519, 0.0746156562280948, 0.25644719230984653)
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10000/10000 [04:53<00:00, 34.05it/s]
# Rec by user emb (0.09143211920529921, 0.08563035897733617, 0.3109370821567184)
# ...

# %% [markdown]
# * DataSet: Ta Feng

# %%
# %run model.py data/tafeng.pkl models/model_tafeng_optuna --num-neighbors 12 --hidden-dims 50 --batch-size 64 --num-epochs 5 --batches-per-epoch 10000 --device 'cuda' --k 20 --num-layers 3 --num-heads 3 --lr 2.63974e-05 --agg_att 'mean'
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10000/10000 [11:47<00:00, 14.13it/s]
# Rec by user emb (0.004551323434473689, 0.020286966044379448, 0.0034472201704137525)
#  Rec by latest item (0.004416511601412519, 0.019537375613145176, 0.0030339311485537233)
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10000/10000 [11:22<00:00, 14.66it/s]
# Rec by user emb (0.005567159077962968, 0.025288881601100193, 0.004099687317760629)
#  Rec by latest item (0.005534880188356769, 0.025211656264831697, 0.0044738662509066504)
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10000/10000 [11:23<00:00, 14.63it/s]
# Rec by user emb (0.00569247711996353, 0.02510770814408756, 0.0037938181527428475)
# ...

# %%
# %run model.py data/tafeng.pkl models/model_tafeng_optuna --num-neighbors 12 --hidden-dims 50 --batch-size 64 --num-epochs 5 --batches-per-epoch 10000 --device 'cuda' --k 20 --num-layers 1 --num-heads 3 --lr 2.63974e-05 --agg_att 'mean'
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10000/10000 [07:10<00:00, 23.21it/s]
# Rec by user emb (0.005363991949265104, 0.023858611031876843, 0.004443778635125075)
#  Rec by latest item (0.004435499183533809, 0.019733117990029775, 0.003386634016898256)
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10000/10000 [07:10<00:00, 23.24it/s]
# Rec by user emb (0.005722857251357598, 0.025172737020466122, 0.0047604958682432984)
#  Rec by latest item (0.005409562146356212, 0.02398799276971708, 0.004343483881371283)
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10000/10000 [07:10<00:00, 23.23it/s]
# Rec by user emb (0.0060247598070862045, 0.02676002113618986, 0.0051360110830943545)
# ...

# %% [markdown]
# * DataSet: Amazon review data: Video Games

# %%
# %run model.py data/amazon.pkl models/model_amazon_optuna --num-neighbors 6 --hidden-dims 50 --batch-size 64 --num-epochs 5 --batches-per-epoch 10000 --device 'cuda' --k 20 --num-layers 1 --num-heads 2 --lr 0.00023437 --agg_att 'mean'
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10000/10000 [04:31<00:00, 36.88it/s]
# Rec by user emb (0.007811262866191621, 0.06228034414183227, 0.008754692217300604)
#  Rec by latest item (0.00470605700712575, 0.03693823663240462, 0.0026772061050859583)
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10000/10000 [04:33<00:00, 36.59it/s]
# Rec by user emb (0.009642220902613125, 0.0776100895539347, 0.012874220191501213)
#  Rec by latest item (0.005069774346793192, 0.04066325863446211, 0.0037436392110338796)
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10000/10000 [04:11<00:00, 39.73it/s]
# Rec by user emb (0.010045526524149192, 0.08208097169170069, 0.013428535154615997)
# ...
